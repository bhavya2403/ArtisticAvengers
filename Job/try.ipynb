# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./file.csv')

# print(df.head())

# create a new data frame with all the columns except 15 to 25

df1 = df.iloc[:, 0:15]


df1.to_csv('naukri.csv', index=False)

# %%
naukri_df = pd.read_csv('naukri.csv')
indeed_df = pd.read_csv('indeed.csv')

naukri_df = naukri_df.drop(['Age'], axis=1)
indeed_df = indeed_df.drop(['Age'], axis=1)

naukri_df = naukri_df.mean()
indeed_df = indeed_df.mean()

print(naukri_df)
print(indeed_df)
# Out:
# Visibility of System Status                                2.935484
# Match between System and the Real World                    4.064516
# User Control and Freedom                                   3.516129
# Consistency and Standards                                  4.129032
# Error Prevention                                           3.129032
# Recognition rather than Recall                             4.000000
# Flexibility and Efficiency of Use                          3.645161
# Aesthetic and Minimalist Design                            3.354839
# Help Users Recognize, Diagnose, and Recover from Errors    4.032258
# Provision of Help and Documentation                        3.419355
# dtype: float64
# Visibility of System Status                                3.580645
# Match between System and the Real World                    4.129032
# User Control and Freedom                                   4.258065
# Consistency and Standards                                  4.161290
# ...

# %%
plt.figure(figsize=(10, 5))
naukri_df.plot(kind='bar', figsize=(10, 5))

plt.figure(figsize=(10, 5))
indeed_df.plot(kind='bar', figsize=(10, 5))
# Out:
# <AxesSubplot: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dfda = pd.read_csv("naukri.csv")
dfpd = pd.read_csv("indeed.csv")

pltda = dfda.describe().loc['mean'].drop('Age')
pltpd = dfpd.describe().loc['mean'].drop('Age')
X_axis = np.arange(len(pltda.index))
plt.bar(X_axis-.2, pltda, .4, label="naukri.com")
plt.bar(X_axis+.2, pltpd, .4, label="indeed.com")
plt.xticks(X_axis, pltda.index, rotation=90)
plt.xlabel("Heuristics")
plt.ylabel("Rating")
plt.title("Comparison of heuristic evaluation of DAIICT and PDPU")
plt.legend()

plt.show()
