# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_pdpu = pd.read_csv('pdpu.csv')

# find the average of all the columns

# drop the first column

df_pdpu = df_pdpu.drop('Age', axis=1)
df_pdpu.mean()
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_14620\3903763438.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_pdpu.mean()
# Visibility of System Status                                5.35
# Match between System and the Real World                    5.70
# User Control and Freedom                                   5.15
# Consistency and Standards                                  5.60
# Error Prevention                                           5.15
# Recognition rather than Recall                             5.15
# Flexibility and Efficiency of Use                          5.40
# Aesthetic and Minimalist Design                            5.45
# Help Users Recognize, Diagnose, and Recover from Errors    5.15
# ...

# %%
df_daiict = pd.read_csv('daiict.csv')

# find the average of all the columns

df_daiict.mean()

df_daiict = df_daiict.drop('Age', axis=1)

ind = np.arange(10)  # the x locations for the groups

# plot bar graph of the average of all the columns
plt.figure()
df_daiict.mean().plot(kind='bar')

plt.figure()
df_pdpu.mean().plot(kind='bar')
# Out:
# C:\Users\rudra\AppData\Local\Temp\ipykernel_14620\2184191139.py:5: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_daiict.mean()
# C:\Users\rudra\AppData\Local\Temp\ipykernel_14620\2184191139.py:13: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_daiict.mean().plot(kind='bar')
# ...
